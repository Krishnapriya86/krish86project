# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("C:\\Users\\jithi\\Desktop\\lung_cancer_data.csv")

# %%
df.head()
# Out:
#    Patient_ID  Age  Gender Smoking_History  Years_Smoked  Pack_Years  \
# 0           1   69    Male           Never            30           3
# 1           2   32  Female          Former             6          61
# 2           3   89    Male           Never             2           9
# 3           4   78  Female           Never            11          69
# 4           5   38    Male          Former            11          57
#
#    Family_History_Cancer      Occupation  Exposure_to_Toxins Residential_Area  \
# 0                  False          Farmer               False            Urban
# 1                  False   Office Worker               False            Urban
# 2                   True   Office Worker                True            Rural
# 3                  False  Factory Worker                True            Urban
# 4                  False          Farmer               False            Rural
#
#    ...  Previous_Cancer_Diagnosis  Tumor_Size_cm  Metastasis_Status  \
# 0  ...                       True          11.02               True
# 1  ...                      False          14.29               True
# 2  ...                      False           9.47              False
# 3  ...                      False           2.22              False
# 4  ...                      False           8.26              False
#
#    Stage_of_Cancer  Treatment_Type  Survival_Years Follow_Up_Visits  \
# 0              III         Surgery              12               24
# 1               II    Chemotherapy               6               12
# 2              III    Chemotherapy               6               15
# 3               IV    Chemotherapy              13               25
# 4              III      Palliative               3                4
#
#   Medication_Response  Symptom_Progression Year_of_Diagnosis
# 0                Good               Stable              2007
# 1                Poor               Stable              2009
# 2                Good            Worsening              2015
# 3            Moderate            Improving              2012
# 4                Good               Stable              2014
#
# [5 rows x 30 columns]

# %%
df.columns
# Out:
# Index(['Patient_ID', 'Age', 'Gender', 'Smoking_History', 'Years_Smoked',
#        'Pack_Years', 'Family_History_Cancer', 'Occupation',
#        'Exposure_to_Toxins', 'Residential_Area', 'BMI',
#        'Lung_Function_Test_Result', 'Chest_Pain_Symptoms',
#        'Shortness_of_Breath', 'Chronic_Cough', 'Weight_Loss',
#        'Physical_Activity_Level', 'Dietary_Habits', 'Air_Quality_Index',
#        'Comorbidities', 'Previous_Cancer_Diagnosis', 'Tumor_Size_cm',
#        'Metastasis_Status', 'Stage_of_Cancer', 'Treatment_Type',
#        'Survival_Years', 'Follow_Up_Visits', 'Medication_Response',
#        'Symptom_Progression', 'Year_of_Diagnosis'],
#       dtype='object')

# %%
df.shape
# Out:
# (300000, 27)

# %%
unwanted_columns = ['Patient_ID', 'Occupation', 'Residential_Area']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Patient_ID                 300000 non-null  int32
#  1   Age                        300000 non-null  int32
#  2   Gender                     300000 non-null  int32
#  3   Smoking_History            300000 non-null  int32
#  4   Years_Smoked               300000 non-null  int64
#  5   Family_History_Cancer      300000 non-null  bool
#  6   Occupation                 300000 non-null  int32
#  7   Exposure_to_Toxins         300000 non-null  bool
#  8   Residential_Area           300000 non-null  int32
#  9   Lung_Function_Test_Result  300000 non-null  float64
#  10  Chest_Pain_Symptoms        300000 non-null  bool
#  11  Shortness_of_Breath        300000 non-null  bool
#  12  Chronic_Cough              300000 non-null  bool
#  13  Weight_Loss                300000 non-null  bool
#  14  Physical_Activity_Level    300000 non-null  int32
#  15  Dietary_Habits             300000 non-null  int32
#  16  Air_Quality_Index          300000 non-null  int64
#  17  Previous_Cancer_Diagnosis  300000 non-null  bool
#  18  Tumor_Size_cm              300000 non-null  float64
#  19  Metastasis_Status          300000 non-null  bool
#  20  Stage_of_Cancer            300000 non-null  object
#  21  Treatment_Type             300000 non-null  object
#  22  Survival_Years             300000 non-null  int64
#  23  Follow_Up_Visits           300000 non-null  int64
#  24  Medication_Response        300000 non-null  object
#  25  Symptom_Progression        300000 non-null  object
#  26  Year_of_Diagnosis          300000 non-null  int64
# dtypes: bool(8), float64(2), int32(8), int64(5), object(4)
# memory usage: 36.6+ MB

# %%
df.isnull().sum()
# Out:
# Patient_ID                   0
# Age                          0
# Gender                       0
# Smoking_History              0
# Years_Smoked                 0
# Family_History_Cancer        0
# Occupation                   0
# Exposure_to_Toxins           0
# Residential_Area             0
# Lung_Function_Test_Result    0
# Chest_Pain_Symptoms          0
# Shortness_of_Breath          0
# Chronic_Cough                0
# Weight_Loss                  0
# Physical_Activity_Level      0
# Dietary_Habits               0
# Air_Quality_Index            0
# Previous_Cancer_Diagnosis    0
# Tumor_Size_cm                0
# Metastasis_Status            0
# Stage_of_Cancer              0
# Treatment_Type               0
# Survival_Years               0
# Follow_Up_Visits             0
# Medication_Response          0
# Symptom_Progression          0
# Year_of_Diagnosis            0
# dtype: int64

# %%
categorical_cols = ['Gender', 'Smoking_History', 'Occupation', 'Residential_Area',
                    'Physical_Activity_Level', 'Dietary_Habits', 'Comorbidities',
                    'Stage_of_Cancer', 'Treatment_Type', 'Medication_Response', 'Symptom_Progression']

# %%
label_encoders = {}
categorical_columns = df.select_dtypes(include=['object']).columns
for col in categorical_columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le

# %%
df.head(10)
# Out:
#    Patient_ID  Age  Gender  Smoking_History  Years_Smoked  \
# 0           0   47       1                2            30
# 1       12351    6       0                1             6
# 2      135807   69       1                2             2
# 3      148153   57       0                2            11
# 4      160498   13       1                1            11
# 5      172843   16       0                0             9
# 6      185188   12       0                0            29
# 7      197533   14       0                2            49
# 8      209878   48       0                2             2
# 9           1    1       0                1            31
#
#    Family_History_Cancer  Occupation  Exposure_to_Toxins  Residential_Area  \
# 0                  False           1               False                 2
# 1                  False           2               False                 2
# 2                   True           2                True                 0
# 3                  False           0                True                 2
# 4                  False           1               False                 0
# 5                  False           3               False                 2
# 6                  False           2               False                 0
# 7                   True           0                True                 1
# 8                  False           2                True                 1
# 9                  False           1                True                 0
#
#    Lung_Function_Test_Result  ...  Previous_Cancer_Diagnosis  Tumor_Size_cm  \
# 0                       38.1  ...                       True          11.02
# 1                       95.1  ...                      False          14.29
# 2                       62.4  ...                      False           9.47
# 3                       62.9  ...                      False           2.22
# 4                       70.6  ...                      False           8.26
# 5                       95.9  ...                      False           5.72
# 6                       67.9  ...                      False           1.05
# 7                       39.9  ...                      False          14.50
# 8                       88.0  ...                       True           5.03
# 9                       57.8  ...                      False           0.72
#
#    Metastasis_Status  Stage_of_Cancer  Treatment_Type  Survival_Years  \
# 0               True                2               3              12
# 1               True                1               0               6
# 2              False                2               0               6
# 3              False                3               0              13
# 4              False                2               1               3
# 5              False                3               0               1
# 6              False                1               0              18
# 7              False                0               2              11
# 8               True                1               2               3
# 9              False                0               0              18
#
#    Follow_Up_Visits  Medication_Response  Symptom_Progression  \
# 0                24                    0                    1
# 1                12                    2                    1
# 2                15                    0                    2
# 3                25                    1                    0
# 4                 4                    0                    1
# 5                39                    2                    2
# 6                34                    0                    1
# 7                26                    1                    2
# 8                22                    0                    2
# 9                19                    1                    1
#
#    Year_of_Diagnosis
# 0               2007
# 1               2009
# 2               2015
# 3               2012
# 4               2014
# 5               2020
# 6               2002
# 7               2015
# 8               2016
# 9               2022
#
# [10 rows x 27 columns]
